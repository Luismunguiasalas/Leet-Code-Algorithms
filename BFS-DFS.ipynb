# %%
# 617. Merge Two Binary Trees

# You are given two binary trees root1 and root2.

# Imagine that when you put one of them to cover the other, some nodes of the two trees are overlapped while the others are not. You need to merge the two trees into a new binary tree. The merge rule is that if two nodes overlap, then sum node values up as the new value of the merged node. Otherwise, the NOT null node will be used as the node of the new tree.

# Return the merged tree.

# Note: The merging process must start from the root nodes of both trees.

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def mergeTrees(self, root1: Optional[TreeNode], root2: Optional[TreeNode]) -> Optional[TreeNode]:
        if root1 is None and root2 is None:
            return None
        elif root1 is None and root2 is not None:
            return root2
        elif root1 is not None and root2 is None:
            return root1
        else:
            def helper(one, two):
                while one is not None and two is not None:
                    one.val += two.val
                    if one.left is not None and two.left is not None:
                        helper(one.left, two.left)
                    if one.right is not None and two.right is not None:
                        helper(one.right, two.right)
                    if one.left is None or one.right is None:
                        if one.left is None and two.left is not None:
                            one.left = two.left
                        if one.right is None and two.right is not None:
                            one.right = two.right
                    return
                return
            helper(root1, root2)
            return root1
  
# Time O(N) - interate over N nodes
  # Space O(N) - stack space
# Runtime: 87ms, beats 85% of python 3 submissions

# %%
# 116. Populating Next Right Pointers in Each Node
# You are given a perfect binary tree where all leaves are on the same level, and every parent has two children. The binary tree has the following definition:
# Populate each next pointer to point to its next right node. If there is no next right node, the next pointer should be set to NULL.

# Initially, all next pointers are set to NULL.

"""
# Definition for a Node.
class Node:
    def __init__(self, val: int = 0, left: 'Node' = None, right: 'Node' = None, next: 'Node' = None):
        self.val = val
        self.left = left
        self.right = right
        self.next = next
"""

class Solution:
    def connect(self, root: 'Optional[Node]') -> 'Optional[Node]':
        if root is None:
            return root
        arr = []
        queue = [root]
        while queue != []:
            node = queue.pop(0)
            arr.append(node)
            if node.left is not None:
                queue.append(node.left)
            if node.right is not None:
                queue.append(node.right)
        curr = 1
        for i in range(len(arr)):
            if i+1 == curr:
                arr[i].next = None
                curr = (curr * 2) + 1
            else: arr[i].next = arr[i+1]
        return root

# O(N) Time, Space O(N)
# runtime: 69ms, beats 74%


"""
# Definition for a Node.
class Node:
    def __init__(self, val: int = 0, left: 'Node' = None, right: 'Node' = None, next: 'Node' = None):
        self.val = val
        self.left = left
        self.right = right
        self.next = next
"""
#BFS

class Solution:
    def connect(self, root: 'Optional[Node]') -> 'Optional[Node]':
        if root is None:
            return root
        stack = [None]
        def helper(node):
            while node is not None:
                node.next = stack[-1]
                if stack[-1] is not None:
                    stack.pop()
                
                if node.right is not None:
                    helper(node.right)
                
                if node.right is None and node.left is None:
                    if stack != []:
                        stack.pop()
                    stack.append(node)
                    return

                if node.left is not None:
                    helper(node.left)
                    stack.append(node)
                return
        helper(root)
        return root
      
# O(N) Time, Space O(N)
# Runtime: 56ms, beats 98% of python submissions

# %%
# 733. Flood Fill

# An image is represented by an m x n integer grid image where image[i][j] represents the pixel value of the image.

# You are also given three integers sr, sc, and color. You should perform a flood fill on the image starting from the pixel image[sr][sc].

# To perform a flood fill, consider the starting pixel, plus any pixels connected 4-directionally to the starting pixel of the same color as the starting pixel, plus any pixels connected 4-directionally to those pixels (also with the same color), and so on. Replace the color of all of the aforementioned pixels with color.

# Return the modified image after performing the flood fill.

# DFS recursive solution
class Solution:
    def floodFill(self, image: List[List[int]], sr: int, sc: int, color: int) -> List[List[int]]:
        starting_pixel = image[sr][sc]
        row_length = len(image) - 1
        col_length = len(image[0]) - 1

        def helper(row,column):
            while 0 <= row <= row_length and  0 <= column <= col_length:
                
                if image[row][column] == starting_pixel:
                    image[row][column] = color

                    if row - 1 >= 0 and image[row -1 ][column] != color:
                        helper(row - 1, column)

                    if column - 1 >= 0 and image[row][column - 1] != color:
                        helper(row, column - 1)

                    if row + 1 <= row_length and image[row + 1][column] != color:
                        helper(row + 1, column)

                    if column + 1 <= col_length and image[row][column + 1] != color:
                        helper(row, column + 1)
                    return
                        
                else:
                    return
        helper(sr, sc)
        return image
Console

# Time O(N+M) size of matrix, Space O(N+M) stack size
# Runtime: 70ms, beats 98% of python submissions

# %%
# 695. Max Area of Island

# You are given an m x n binary matrix grid. An island is a group of 1's (representing land) connected 4-directionally (horizontal or vertical.) You may assume all four edges of the grid are surrounded by water.

# The area of an island is the number of cells with a value 1 in the island.

# Return the maximum area of an island in grid. If there is no island, return 0.

class Solution:
    def maxAreaOfIsland(self, grid: List[List[int]]) -> int:
        len_col = len(grid[0]) - 1
        len_row = len(grid) - 1
        output = 0
        max_area = []
        def helper(row, column, ttl):
            while 0 <= row <= len_row and 0 <= column <= len_col:
                if grid[row][column] == 1:
                    max_area.append(1)
                    grid[row][column] = 0

                    if row - 1 >= 0 and grid[row - 1][column] != 0:
                        helper(row - 1, column, ttl + 1)
                    if column - 1 >= 0 and grid[row][column - 1] != 0:
                        helper(row, column - 1, ttl + 1)
                    if row + 1 <= len_row and grid[row + 1][column] != 0:
                        helper(row + 1, column, ttl + 1)
                    if column + 1 <= len_col and grid[row][column + 1] != 0:
                        helper(row, column + 1, ttl + 1)
                    return
                return

        for row in range(len_row + 1):
            for col in range(len_col + 1):
                if grid[row][col] == 1:
                    helper(row, col, ttl = 1)
                    output = max(output, sum(max_area))
                    max_area.clear()
        
        return output
      
# Time O(N+M), Space O(N+M)

# Runtime: 126ms, beats 97% of python submissions

class Solution:
    def maxAreaOfIsland(self, grid: List[List[int]]) -> int:
        len_col = len(grid[0]) - 1
        len_row = len(grid) - 1
        output = 0
        max_area = []
        def helper(row, column, ttl):
            while 0 <= row <= len_row and 0 <= column <= len_col:
                if grid[row][column] == 1:
                    max_area.append(1)
                    grid[row][column] = 0

                    if row - 1 >= 0 and grid[row - 1][column] != 0:
                        helper(row - 1, column, ttl + 1)
                    if column - 1 >= 0 and grid[row][column - 1] != 0:
                        helper(row, column - 1, ttl + 1)
                    if row + 1 <= len_row and grid[row + 1][column] != 0:
                        helper(row + 1, column, ttl + 1)
                    if column + 1 <= len_col and grid[row][column + 1] != 0:
                        helper(row, column + 1, ttl + 1)
                    return
                return

        for row in range(len_row + 1):
            for col in range(len_col + 1):
                if grid[row][col] == 1:
                    helper(row, col, ttl = 1)
                    output = max(output, sum(max_area))
                    max_area.clear()
                    if output == (len_col + 1) * (len_row + 1): # added this to avoid iterating over matrix if already found max_area i.e., m*n
                        return output
        
        return output
    
    
# Time O(N+M), Space O(N+M)
# Runtime: 116ms, beats 99.34% of pythons submissions for this problem

# %%
# 994. Rotting Oranges
# You are given an m x n grid where each cell can have one of three values:

# 0 representing an empty cell,
# 1 representing a fresh orange, or
# 2 representing a rotten orange.
# Every minute, any fresh orange that is 4-directionally adjacent to a rotten orange becomes rotten.

# Return the minimum number of minutes that must elapse until no cell has a fresh orange. If this is impossible, return -1.


class Solution:
    def orangesRotting(self, grid: List[List[int]]) -> int:
        row_len = len(grid) - 1
        col_len = len(grid[0]) - 1
        # function will check if apple is Isolated 4-directionally, 3-directionally, 2-directionally
        # function should only be initiated before a rotten apple is encountered
        # or encountering an apple after a zero
        def checkIsolated(row,col):
            found_apple = 0
            if row > 0:
                if grid[row - 1][col] != 0:
                    found_apple += 1
            if row < row_len:
                if grid[row + 1][col] != 0:
                    found_apple += 1
            if col < col_len:
                if grid[row][col + 1] != 0:
                    found_apple += 1
            if col > 0:
                if grid[row][col - 1] != 0:
                    found_apple += 1
            if found_apple == 0:
                return -1
        return 0

        # def helper(row_len, col_len):
            # for row in range(row_len + 1):
                # for col in range(col_len + 1):
                    # node = grid[row][col]
                    
                    # if 
                    # if row 
                    
                    
                    
                    
                    
class Solution:
    def orangesRotting(self, grid: List[List[int]]) -> int:

        # function will check if apple is Isolated 4-directionally, 3-directionally, 2-directionally
        # function should only be initiated before a rotten apple is encountered
        # or encountering an apple after a zero
        def checkIsolated(row,col):
            found_apple = 0
            if row > 0:
                if grid[row - 1][col] != 0:
                    found_apple += 1
            if row < row_len:
                if grid[row + 1][col] != 0:
                    found_apple += 1
            if col < col_len:
                if grid[row][col + 1] != 0:
                    found_apple += 1
            if col > 0:
                if grid[row][col - 1] != 0:
                    found_apple += 1
            if found_apple == 0:
                return True
            return False
            

        # breath-first-search
        # function will check if fresh apples are around 4-directionally, 3-directionally, 2-directionally
        # function should only be initiated when encountered a rotten apple (2)
        # if fresh apples are round, change fresh apples (1) to rotten apples(2)
        # keep track of max distance from
        def checkFreshApples(row,col):
            # print(row + col)
            if grid[row][col] != 2 and max_distance[0] < row + col:
                max_distance[0] = row + col
            grid[row][col] = 0
            print(max_distance[0], "here")
            if row > 0 and grid[row - 1][col] == 1:
                    checkFreshApples(row - 1,col)
            if row < row_len and grid[row + 1][col] == 1:
                    checkFreshApples(row + 1,col)
            if col < col_len and grid[row][col + 1] == 1:
                    checkFreshApples(row,col + 1)
            if col > 0 and grid[row][col - 1] == 1:
                    checkFreshApples(row,col - 1)
            if max_distance[0] == 0:
                return -1
            return max_distance[0]

        row_len = len(grid) - 1
        col_len = len(grid[0]) - 1

        output = 0
        max_distance = [0]

        for row in range(row_len + 1):
            for col in range(col_len + 1):
                if grid[row][col] == 2:
                    # print("INN 2")
                    temp = checkFreshApples(row,col)
                    if temp != -1:
                        if temp == 0:
                            output = max(output, max_distance[0])
                        else:
                            # output = max(output,abs(max_distance[0] - (row + col)))
                            output = max(output,(max_distance[0] - (row + col)))
                    max_distance[0] = 0
                    # print("OUT 2")
                elif grid[row][col] == 1:
                    # print("INN 1")
                    if checkIsolated(row,col):
                        return -1
                    # print("OUT 1")
        return output

# %%
# 1469. Find All The Lonely Nodes
# In a binary tree, a lonely node is a node that is the only child of its parent node.
# The root of the tree is not lonely because it does not have a parent node.

# Given the root of a binary tree, return an array containing the values of all lonely nodes in the tree. Return the list in any order.

class Solution:
  def getLonelyNodes(self, root: Optional[TreeNode]) -> List[int]:
    output = []
    def helper(n):
      while n is not None:
        if n.left is not None:
          helper(n.left)
        if n.right is not None:
          helper(n.right)
        # determine if left is lonely or elif right is lonely
        if n.left is not None and n.right is None:
          output.append(n.left.val)
        elif n.left is None and n.right is not None:
          output.append(n.right.val)
        return
    helper(root)
    return output

# Time O(N), Space(N)

class Solution:
  def getLonelyNodes(self, root: Optional[TreeNode]) -> List[int]:
    output = []
    stack = [root]
    while stack != []:
      node =stack.pop()
      if node.left is not None:
        stack.append(node.left)
      if node.right is not None:
        stack.append(node.right)
      if node.left is not None and node.right is None:
        output.append(node.left.val)
      elif node.left is None and node.right is not None:
        output.append(node.right.val)
      return
    helper(root)
    return output

# %%
# 2331. Evaluate Boolean Binary Tree
# You are given the root of a full binary tree with the following properties:

# Leaf nodes have either the value 0 or 1, where 0 represents False and 1 represents True.
# Non-leaf nodes have either the value 2 or 3, where 2 represents the boolean OR and 3 represents the boolean AND.
# The evaluation of a node is as follows:

# If the node is a leaf node, the evaluation is the value of the node, i.e. True or False.
# Otherwise, evaluate the node's two children and apply the boolean operation of its value with the children's evaluations.
# Return the boolean result of evaluating the root node.

# A full binary tree is a binary tree where each node has either 0 or 2 children.

# A leaf node is a node that has zero children.

class Solution:
  def evaluateTree(self, root: Optional[TreeNode]) -> bool:
    def helper(node):
      while node.left is not None and node.right is not None:
        if node.val == 2:
          return helper(node.left) or helper(node.right)
        else:
          return helper(node.left) or helper(node.right)
      return node.val == 1
    return helper(root)

# %%
# 1038. Binary Search Tree to Greater Sum Tree
# Given the root of a Binary Search Tree (BST), convert it to a Greater Tree such that every key of the original BST is changed to the original key plus the sum of all keys greater than the original key in BST.

# As a reminder, a binary search tree is a tree that satisfies these constraints:

# The left subtree of a node contains only nodes with keys less than the node's key.
# The right subtree of a node contains only nodes with keys greater than the node's key.
# Both the left and right subtrees must also be binary search trees.

class Solution:
  def bstToGst(self, root: TreeNode) -> TreeNode:
    def helper(node, val=0):
      if node.left is None and node.right is None:
        node.val = node.val + val
        return node.val
      
      elif node is not None:
        if node.right is not None:
          node.val += helper(node.right, val)
        if node.right is None:
          node.val += val
        if node.left is not None:
          val = helper(node.left, node.val)
        return max(val, node.val)
      return
    helper(root)
    return root

# %%
# 1315. Sum of Nodes with Even-Valued Grandparent
class Solution:
  def sumEvenGrandparent(self, root: TreeNode) -> int:
    output = [0]
    def helper(node):
      while node is not None:
        helper(node.right)
        helper(node.left)
        if node.val % 2 == 0:
          temp = []
          temp.append(node.left)
          temp.append(node.right)
          for i in temp:
            if i is not None:
              if i.left is not None:
                output[0] += i.left.val
              if i.right is not None:
                output[0] += i.right.val
        return
      return
    helper(root)
    return output[0]
  
  class Solution:
    def sumEvenGrandparent(self, root: TreeNode) -> int:
      output = 0
      stack = [root]
      while stack != []:
        node = stack.pop()
        temp = []
        if node.left is not None:
          stack.apepnd(node.left)
          temp.append(node.left)
        if node.right is not None:
          stack.append(node.right)
          temp.append(node.right)
        if (node.val % 2) == 0:
          for subnode in temp:
            if subnode.left is not None:
              output += subnode.left.val
            if subnode.right is not None:
              output += subnode.right.val
      return output

Time O(n)
